# %% [markdown]
# # (a)

# %%
'''>>>>> start CodeP4.1F21
    V.P. Carey ME249, Fall 2021

Intro to Neural Network Modeling 
Keras model for PV power system'''

#import useful packages
import math
import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf
#the follwoing 2 lines are only needed for Mac OS machines
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# define meadian values of input variables - add your values here
Dmed = 1.  #make sure Tamed does not = 0
Qmed = 1.
Mmed = 1.

#create input data array
xdata = []


#Part 1 input data: Air temp (degC), ID (W/sqm), load resistance (ohms)
#xdata = [[-10.0, 350, 4.464]] 
#xdata.append([-10.0, 650, 4.464]) 
#xdata.append([-10.0, 950, 4.464]) 
#xdata.append([-10.0, 1250, 4.464])
xdata.append([0.008, 550, 0.06157])     #导入新数据
xdata.append([0.008, 650, 0.07269])
xdata.append([0.008, 750, 0.08396])
xdata.append([0.008, 850, 0.09347])
xdata.append([0.008, 950, 0.10635])
xdata.append([0.008, 1050, 0.11521])
xdata.append([0.008, 1150, 0.1287])
xdata.append([0.008, 850, 0.09516])
xdata.append([0.008, 550, 0.04398])
xdata.append([0.008, 750, 0.05997])
xdata.append([0.008, 950, 0.07596])
xdata.append([0.008, 1050, 0.08343])
xdata.append([0.008, 1150, 0.0919])
xdata.append([0.008, 850, 0.06797])
xdata.append([0.008, 550, 0.0342])
xdata.append([0.008, 750, 0.04664])
xdata.append([0.008, 950, 0.05908])
xdata.append([0.008, 1150, 0.0715])
xdata.append([0.008, 850, 0.05286])
xdata.append([0.011, 550, 0.0846])
xdata.append([0.011, 750, 0.1154])
xdata.append([0.011, 950, 0.1462])
xdata.append([0.011, 1150, 0.177])
xdata.append([0.011, 850, 0.1308])
xdata.append([0.011, 550, 0.06047])
xdata.append([0.011, 750, 0.08246])
xdata.append([0.011, 950, 0.1044])
xdata.append([0.011, 1050, 0.1134])
xdata.append([0.011, 1150, 0.1264])
xdata.append([0.011, 850, 0.0934])
xdata.append([0.011, 550, 0.047])
xdata.append([0.011, 750, 0.06413])
xdata.append([0.011, 950, 0.08124])
xdata.append([0.011, 1150, 0.09834])
xdata.append([0.011, 850, 0.072691])
xdata.append([0.011, 700, 0.087196])
xdata.append([0.013, 550, 0.10005])
xdata.append([0.013, 750, 0.13644])
xdata.append([0.013, 950, 0.17282])
xdata.append([0.013, 1150, 0.2092])
xdata.append([0.013, 850, 0.15463])
xdata.append([0.013, 550, 0.07147])
xdata.append([0.013, 750, 0.09745])
xdata.append([0.013, 950, 0.12344])
xdata.append([0.013, 1050, 0.13302])
xdata.append([0.013, 1150, 0.1494])
xdata.append([0.013, 850, 0.11045])
xdata.append([0.013, 550, 0.05558])
xdata.append([0.013, 750, 0.0758])
xdata.append([0.013, 950, 0.09601])
xdata.append([0.013, 1150, 0.1162])
xdata.append([0.013, 850, 0.0859])


''' ADD THE REST OF THE INPUT DATA AND CONVERT TO:
xdata = [[-10.0/Tamed, 350/IDmed, 4.464/RLmed]] 
xdata.append([-10.0/Tamed, 650/IDmed, 4.464/RLmed]) 
xdata.append([-10.0/Tamed, 950/IDmed, 4.464/RLmed]) 
xdata.append([-10.0/Tamed, 1250/IDmed, 4.464/RLmed]) 
... etc.'''



# define meadian values of input variables - add your values here
Xmed = 1.
Tmed = 1

#create input data array
ydata = []

#Part 1 output data: VL (V) and Power out Wd (W)
ydata.append([0.525, 306.7])
ydata.append([0.525, 298.5])
ydata.append([0.525, 294.5])
ydata.append([0.525, 290.2])
ydata.append([0.524, 286.9])
ydata.append([0.524, 284.1])
ydata.append([0.525, 281.7])
ydata.append([0.524, 290.3])
ydata.append([0.734, 307.9])
ydata.append([0.735, 295.5])
ydata.append([0.735, 287.8])
ydata.append([0.735, 285.0])
ydata.append([0.735, 282.5])
ydata.append([0.734, 291.3])
ydata.append([ 0.945, 308.6])
ydata.append([0.945, 296.2])
ydata.append([0.945, 288.5])
ydata.append([0.945, 283.1])
ydata.append([0.945, 291.9])
ydata.append([ 0.525, 328.0])
ydata.append([0.525, 311.2])
ydata.append([0.525, 300.8])
ydata.append([0.525, 293.6])
ydata.append([0.525, 305.5])
ydata.append([0.735, 329.6])
ydata.append([0.735, 312.6])
ydata.append([0.735, 302.0])
ydata.append([0.735, 299.4])
ydata.append([0.735, 294.8])
ydata.append([0.735, 306.8])
ydata.append([ 0.945, 330.7])
ydata.append([0.945, 313.6])
ydata.append([0.944, 302.9])
ydata.append([0.945, 295.6])
ydata.append([0.944, 307.7])
ydata.append([0.734, 324.7])
ydata.append([0.525, 342.2])
ydata.append([0.524,  322.3])
ydata.append([0.524, 310.0])
ydata.append([0.525, 301.6])
ydata.append([0.524, 315.5])
ydata.append([0.734, 344.1])
ydata.append([0.735, 324.0])
ydata.append([0.735, 311.5])
ydata.append([0.735, 306.3])
ydata.append([0.735, 302.9])
ydata.append([0.734, 317.1])
ydata.append([0.945, 345.3])
ydata.append([0.944, 325.1])
ydata.append([0.944, 312.5])
ydata.append([0.945, 303.9])
ydata.append([0.945, 318.2])
''' ADD THE REST OF THE OUPUT DATA AND CONVERT TO:
ydata = [[18.9/VLmed, 80.3/Wdmed]] 
ydata.append([23.5/VLmed, 124.6/Wdmed]) 
ydata.append([24.8/VLmed, 138.6/Wdmed]) 
ydata.append([25.6/VLmed, 146.9/Wdmed]) 
... etc.'''

xarray= np.array(xdata)
yarray= np.array(ydata)
Dmed= np.median(xarray[:,0])
Qmed= np.median(xarray[:,1])
Mmed= np.median(xarray[:,2])
Xmed= np.median(yarray[:,0])
Tmed= np.median(yarray[:,1])



Xmedian = [Dmed,Qmed,Mmed]   # determine median value, divide
Ymedian = [Xmed ,Tmed]
X_nor=xarray/Xmedian
Y_nor=yarray/Ymedian
print(Dmed)
print(Qmed)
print(Mmed)
print(Xmed)
print(Tmed)
print(X_nor)
print(Y_nor)
# Out:
# Using TensorFlow backend.
# 0.011
# 850.0
# 0.09265
# 0.735
# 304.7
# [[0.72727273 0.64705882 0.66454398]
#  [0.72727273 0.76470588 0.78456557]
#  [0.72727273 0.88235294 0.90620615]
#  [0.72727273 1.         1.00885051]
#  [0.72727273 1.11764706 1.14786832]
#  [0.72727273 1.23529412 1.24349703]
#  [0.72727273 1.35294118 1.38909876]
#  [0.72727273 1.         1.0270912 ]
#  [0.72727273 0.64705882 0.47468969]
#  [0.72727273 0.88235294 0.64727469]
#  [0.72727273 1.11764706 0.81985969]
#  [0.72727273 1.23529412 0.9004857 ]
#  [0.72727273 1.35294118 0.99190502]
#  [0.72727273 1.         0.73362115]
#  [0.72727273 0.64705882 0.36913114]
#  [0.72727273 0.88235294 0.50339989]
#  [0.72727273 1.11764706 0.63766865]
#  [0.72727273 1.35294118 0.77172153]
#  [0.72727273 1.         0.57053427]
#  [1.         0.64705882 0.91311387]
#  [1.         0.88235294 1.24554776]
#  [1.         1.11764706 1.57798165]
#  [1.         1.35294118 1.91041554]
#  [1.         1.         1.41176471]
#  [1.         0.64705882 0.65267134]
#  [1.         0.88235294 0.89001619]
#  [1.         1.11764706 1.12682137]
#  [1.         1.23529412 1.22396114]
#  [1.         1.35294118 1.36427415]
#  [1.         1.         1.00809498]
#  [1.         0.64705882 0.50728548]
#  [1.         0.88235294 0.69217485]
#  [1.         1.11764706 0.87684835]
#  [1.         1.35294118 1.06141392]
#  [1.         1.         0.78457636]
#  [1.         0.82352941 0.9411333 ]
#  [1.18181818 0.64705882 1.07987048]
#  [1.18181818 0.88235294 1.47263896]
#  [1.18181818 1.11764706 1.86529951]
#  [1.18181818 1.35294118 2.25796006]
#  [1.18181818 1.         1.66896924]
#  [1.18181818 0.64705882 0.77139773]
#  [1.18181818 0.88235294 1.05180788]
#  [1.18181818 1.11764706 1.33232596]
#  [1.18181818 1.23529412 1.43572585]
#  [1.18181818 1.35294118 1.61252024]
#  [1.18181818 1.         1.19212089]
#  [1.18181818 0.64705882 0.59989207]
#  [1.18181818 0.88235294 0.81813276]
#  [1.18181818 1.11764706 1.03626552]
#  [1.18181818 1.35294118 1.25418241]
#  [1.18181818 1.         0.92714517]]
# [[0.71428571 1.00656383]
#  [0.71428571 0.97965212]
#  [0.71428571 0.96652445]
#  [0.71428571 0.95241221]
#  [0.71292517 0.94158188]
#  [0.71292517 0.93239252]
#  [0.71428571 0.92451592]
#  [0.71292517 0.9527404 ]
#  [0.99863946 1.01050213]
#  [1.         0.96980637]
#  [1.         0.94453561]
#  [1.         0.93534624]
#  [1.         0.92714145]
#  [0.99863946 0.95602232]
#  [1.28571429 1.01279947]
#  [1.28571429 0.97210371]
#  [1.28571429 0.94683295]
#  [1.28571429 0.9291106 ]
#  [1.28571429 0.95799147]
#  [0.71428571 1.07646866]
#  [0.71428571 1.02133246]
#  [0.71428571 0.98720053]
#  [0.71428571 0.96357073]
#  [0.71428571 1.00262553]
#  [1.         1.08171972]
#  [1.         1.02592714]
#  [1.         0.99113883]
#  [1.         0.98260584]
#  [1.         0.96750903]
#  [1.         1.00689202]
#  [1.28571429 1.08532983]
#  [1.28571429 1.02920906]
#  [1.28435374 0.99409255]
#  [1.28571429 0.97013456]
#  [1.28435374 1.00984575]
#  [0.99863946 1.06563833]
#  [0.71428571 1.12307187]
#  [0.71292517 1.05776173]
#  [0.71292517 1.01739416]
#  [0.71428571 0.98982606]
#  [0.71292517 1.0354447 ]
#  [0.99863946 1.12930752]
#  [1.         1.06334099]
#  [1.         1.02231703]
#  [1.         1.00525107]
#  [1.         0.99409255]
#  [0.99863946 1.04069577]
#  [1.28571429 1.13324582]
#  [1.28435374 1.0669511 ]
#  [1.28435374 1.02559895]
#  [1.28571429 0.99737447]
#  [1.28571429 1.04430587]]

# %% [markdown]
# # (b)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_nor, Y_nor, test_size=1/4)

# %% [markdown]
# # (c)  3 hidden layers --> 4 hidden layers

# %%
# define neural network model

#As seen below, we have created four dense layers. 
#A dense layer is a layer in neural network that’s fully connected. 
#In other words, all the neurons in one layer are connected to all other neurons in the next layer.
#In the first layer, we need to provide the input shape, which is 1 in our case. 
#The activation function we have chosen is elu, which stands for exponential linear unit. .

from keras import backend as K
#initialize weights with values between -0.2 and 0.5
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.5)

model = keras.Sequential([   # dense层：全连接   activation:激活函数
    keras.layers.Dense(6, activation=K.elu, input_shape=[3],  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(12, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(16, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(8, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(2,  kernel_initializer=initializer)
  ])
# Out:
# 2021-12-06 23:08:30.060639: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-06 23:08:30.060859: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 4. Tune using inter_op_parallelism_threads for best performance.

# %%
#We’re using RMSprop as our optimizer here. RMSprop stands for Root Mean Square Propagation. 
#It’s one of the most popular gradient descent optimization algorithms for deep learning networks. 
#RMSprop is an optimizer that’s reliable and fast.
#We’re compiling the mode using the model.compile function. The loss function used here 
#is mean squared error. After the compilation of the model, we’ll use the fit method with ~500 epochs.
#Number of epochs can be varied.

#from tf.keras import optimizers
rms = keras.optimizers.RMSprop(0.000020)
model.compile(loss='mean_absolute_error',optimizer=rms)

# %%
#After the compilation of the model, we’ll use the fit method with 500 epochs.
#I started with epochs value of 100 and then tested the model after training. 
#The prediction was not that good. Then I modified the number of epochs to 200 and tested the model again. 
#Accuracy had improved slightly, but figured I’d give it one more try. Finally, at 500 epochs 
#I found acceptable prediction accuracy.

#The fit method takes three parameters; namely, x, y, and number of epochs. 
#During model training, if all the batches of data are seen by the model once, 
#we say that one epoch has been completed.

# Add an early stopping callback
es = keras.callbacks.EarlyStopping(   #callback:回调函数
    monitor='loss', 
    mode='min', 
    patience = 80, 
    restore_best_weights = True, 
    verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss', 
                     mode='min',  verbose=1, save_best_only=True)

historyData = model.fit(X_train,Y_train,epochs=500,callbacks=[es])

loss_hist = historyData.history['loss']
#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))

model.save('./best_model')
# Out:
# Epoch 1/500
# 39/39 [==============================] - 2s 44ms/step - loss: 0.0472
# Epoch 2/500
# 39/39 [==============================] - 0s 579us/step - loss: 0.0536
# Epoch 3/500
# 39/39 [==============================] - 0s 923us/step - loss: 0.0553
# Epoch 4/500
# 39/39 [==============================] - 0s 654us/step - loss: 0.0620
# Epoch 5/500
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0600
# Epoch 6/500
# 39/39 [==============================] - 0s 614us/step - loss: 0.0599
# Epoch 7/500
# 39/39 [==============================] - 0s 642us/step - loss: 0.0616
# Epoch 8/500
# 39/39 [==============================] - 0s 827us/step - loss: 0.0587
# Epoch 9/500
# 39/39 [==============================] - 0s 701us/step - loss: 0.0595
# Epoch 10/500
# 39/39 [==============================] - ETA: 0s - loss: 0.050 - 0s 556us/step - loss: 0.0482
# Epoch 11/500
# 39/39 [==============================] - 0s 539us/step - loss: 0.0604
# Epoch 12/500
# 39/39 [==============================] - 0s 466us/step - loss: 0.0515
# Epoch 13/500
# 39/39 [==============================] - 0s 448us/step - loss: 0.0523
# Epoch 14/500
# 39/39 [==============================] - 0s 583us/step - loss: 0.0516
# Epoch 15/500
# 39/39 [==============================] - 0s 383us/step - loss: 0.0549
# Epoch 16/500
# 39/39 [==============================] - 0s 500us/step - loss: 0.0604
# Epoch 17/500
# 39/39 [==============================] - 0s 549us/step - loss: 0.0611
# Epoch 18/500
# 39/39 [==============================] - 0s 332us/step - loss: 0.0620
# Epoch 19/500
# 39/39 [==============================] - 0s 287us/step - loss: 0.0568
# Epoch 20/500
# 39/39 [==============================] - 0s 468us/step - loss: 0.0577
# Epoch 21/500
# 39/39 [==============================] - 0s 865us/step - loss: 0.0543
# Epoch 22/500
# 39/39 [==============================] - 0s 844us/step - loss: 0.0570
# Epoch 23/500
# 39/39 [==============================] - 0s 676us/step - loss: 0.0614
# Epoch 24/500
# 39/39 [==============================] - 0s 948us/step - loss: 0.0500
# Epoch 25/500
# 39/39 [==============================] - 0s 557us/step - loss: 0.0563
# Epoch 26/500
# 39/39 [==============================] - 0s 981us/step - loss: 0.0558
# Epoch 27/500
# 39/39 [==============================] - 0s 669us/step - loss: 0.0593
# Epoch 28/500
# 39/39 [==============================] - 0s 906us/step - loss: 0.0645
# Epoch 29/500
# 39/39 [==============================] - 0s 711us/step - loss: 0.0605
# Epoch 30/500
# 39/39 [==============================] - 0s 814us/step - loss: 0.0593
# Epoch 31/500
# 39/39 [==============================] - 0s 622us/step - loss: 0.0471
# Epoch 32/500
# 39/39 [==============================] - 0s 924us/step - loss: 0.0560
# Epoch 33/500
# 39/39 [==============================] - 0s 521us/step - loss: 0.0532
# Epoch 34/500
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0641
# Epoch 35/500
# 39/39 [==============================] - 0s 683us/step - loss: 0.0580
# Epoch 36/500
# 39/39 [==============================] - 0s 391us/step - loss: 0.0633
# Epoch 37/500
# 39/39 [==============================] - 0s 627us/step - loss: 0.0545
# Epoch 38/500
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0639
# Epoch 39/500
# 39/39 [==============================] - 0s 644us/step - loss: 0.0565
# Epoch 40/500
# 39/39 [==============================] - 0s 386us/step - loss: 0.0531
# Epoch 41/500
# 39/39 [==============================] - 0s 430us/step - loss: 0.0463
# Epoch 42/500
# 39/39 [==============================] - 0s 529us/step - loss: 0.0550
# Epoch 43/500
# 39/39 [==============================] - 0s 393us/step - loss: 0.0522
# Epoch 44/500
# 39/39 [==============================] - 0s 597us/step - loss: 0.0600
# Epoch 45/500
# 39/39 [==============================] - 0s 377us/step - loss: 0.0506
# Epoch 46/500
# 39/39 [==============================] - 0s 772us/step - loss: 0.0582
# Epoch 47/500
# 39/39 [==============================] - 0s 629us/step - loss: 0.0615
# Epoch 48/500
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0617
# Epoch 49/500
# 39/39 [==============================] - 0s 878us/step - loss: 0.0574
# Epoch 50/500
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0656
# Epoch 51/500
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0609
# Epoch 52/500
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0594
# Epoch 53/500
# 39/39 [==============================] - 0s 900us/step - loss: 0.0528
# Epoch 54/500
# 39/39 [==============================] - 0s 614us/step - loss: 0.0581
# Epoch 55/500
# 39/39 [==============================] - 0s 813us/step - loss: 0.0501
# Epoch 56/500
# 39/39 [==============================] - 0s 894us/step - loss: 0.0548
# Epoch 57/500
# 39/39 [==============================] - 0s 443us/step - loss: 0.0585
# Epoch 58/500
# 39/39 [==============================] - 0s 509us/step - loss: 0.0580
# Epoch 59/500
# 39/39 [==============================] - 0s 536us/step - loss: 0.0555
# Epoch 60/500
# 39/39 [==============================] - 0s 783us/step - loss: 0.0588
# Epoch 61/500
# 39/39 [==============================] - 0s 863us/step - loss: 0.0643
# Epoch 62/500
# 39/39 [==============================] - 0s 684us/step - loss: 0.0554
# Epoch 63/500
# 39/39 [==============================] - 0s 495us/step - loss: 0.0547
# Epoch 64/500
# 39/39 [==============================] - 0s 458us/step - loss: 0.0574
# Epoch 65/500
# 39/39 [==============================] - 0s 479us/step - loss: 0.0557
# Epoch 66/500
# 39/39 [==============================] - 0s 404us/step - loss: 0.0552
# Epoch 67/500
# 39/39 [==============================] - 0s 643us/step - loss: 0.0535
# Epoch 68/500
# 39/39 [==============================] - 0s 501us/step - loss: 0.0529
# Epoch 69/500
# 39/39 [==============================] - 0s 719us/step - loss: 0.0537
# Epoch 70/500
# 39/39 [==============================] - 0s 542us/step - loss: 0.0523
# Epoch 71/500
# 39/39 [==============================] - 0s 506us/step - loss: 0.0575
# Epoch 72/500
# 39/39 [==============================] - 0s 538us/step - loss: 0.0583
# Epoch 73/500
# 39/39 [==============================] - 0s 545us/step - loss: 0.0555
# Epoch 74/500
# 39/39 [==============================] - 0s 413us/step - loss: 0.0565
# Epoch 75/500
# 39/39 [==============================] - 0s 427us/step - loss: 0.0603
# Epoch 76/500
# 39/39 [==============================] - 0s 375us/step - loss: 0.0628
# Epoch 77/500
# 39/39 [==============================] - 0s 289us/step - loss: 0.0603
# Epoch 78/500
# 39/39 [==============================] - 0s 317us/step - loss: 0.0584
# Epoch 79/500
# 39/39 [==============================] - 0s 535us/step - loss: 0.0527
# Epoch 80/500
# 39/39 [==============================] - 0s 615us/step - loss: 0.0666
# Epoch 81/500
# 39/39 [==============================] - 0s 477us/step - loss: 0.0618
# Epoch 82/500
# 39/39 [==============================] - 0s 635us/step - loss: 0.0583
# Epoch 83/500
# 39/39 [==============================] - 0s 385us/step - loss: 0.0537
# Epoch 84/500
# 39/39 [==============================] - 0s 711us/step - loss: 0.0584
# Epoch 85/500
# 39/39 [==============================] - 0s 593us/step - loss: 0.0602
# Epoch 86/500
# 39/39 [==============================] - 0s 513us/step - loss: 0.0556
# Epoch 87/500
# 39/39 [==============================] - 0s 500us/step - loss: 0.0524
# Epoch 88/500
# 39/39 [==============================] - 0s 435us/step - loss: 0.0601
# Epoch 89/500
# 39/39 [==============================] - 0s 549us/step - loss: 0.0573
# Epoch 90/500
# 39/39 [==============================] - 0s 650us/step - loss: 0.0576
# Epoch 91/500
# 39/39 [==============================] - 0s 618us/step - loss: 0.0512
# Epoch 92/500
# 39/39 [==============================] - 0s 420us/step - loss: 0.0565
# Epoch 93/500
# 39/39 [==============================] - 0s 599us/step - loss: 0.0587
# Epoch 94/500
# 39/39 [==============================] - 0s 462us/step - loss: 0.0464
# Epoch 95/500
# 39/39 [==============================] - 0s 482us/step - loss: 0.0559
# Epoch 96/500
# 39/39 [==============================] - 0s 651us/step - loss: 0.0547
# Epoch 97/500
# 39/39 [==============================] - 0s 554us/step - loss: 0.0520
# Epoch 98/500
# 39/39 [==============================] - 0s 521us/step - loss: 0.0606
# Epoch 99/500
# 39/39 [==============================] - 0s 479us/step - loss: 0.0596
# Epoch 100/500
# 39/39 [==============================] - 0s 687us/step - loss: 0.0557
# Epoch 101/500
# 39/39 [==============================] - 0s 739us/step - loss: 0.0631
# Epoch 102/500
# 39/39 [==============================] - 0s 464us/step - loss: 0.0526
# Epoch 103/500
# 39/39 [==============================] - 0s 501us/step - loss: 0.0651
# Epoch 104/500
# 39/39 [==============================] - 0s 921us/step - loss: 0.0618
# Epoch 105/500
# 39/39 [==============================] - 0s 384us/step - loss: 0.0533
# Epoch 106/500
# 39/39 [==============================] - 0s 423us/step - loss: 0.0595
# Epoch 107/500
# 39/39 [==============================] - 0s 441us/step - loss: 0.0657
# Epoch 108/500
# 39/39 [==============================] - 0s 704us/step - loss: 0.0542
# Epoch 109/500
# 39/39 [==============================] - 0s 713us/step - loss: 0.0543
# Epoch 110/500
# 39/39 [==============================] - 0s 889us/step - loss: 0.0586
# Epoch 111/500
# 39/39 [==============================] - 0s 411us/step - loss: 0.0638
# Epoch 112/500
# 39/39 [==============================] - 0s 827us/step - loss: 0.0614
# Epoch 113/500
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0568
# Epoch 114/500
# 39/39 [==============================] - 0s 810us/step - loss: 0.0574
# Epoch 115/500
# 39/39 [==============================] - 0s 521us/step - loss: 0.0536
# Epoch 116/500
# 39/39 [==============================] - 0s 493us/step - loss: 0.0524
# Epoch 117/500
# 39/39 [==============================] - 0s 566us/step - loss: 0.0621
# Epoch 118/500
# 39/39 [==============================] - 0s 453us/step - loss: 0.0692
# Epoch 119/500
# 39/39 [==============================] - 0s 393us/step - loss: 0.0564
# Epoch 120/500
# 39/39 [==============================] - 0s 575us/step - loss: 0.0582
# Epoch 121/500
# 39/39 [==============================] - 0s 509us/step - loss: 0.0589
# Restoring model weights from the end of the best epoch
# Epoch 00121: early stopping
# best epoch =  41
# smallest loss = 0.04629428770679694

# %% [markdown]
# # (e)

# %%
test = []
outpt=[]

for i in range(len(X_train)):
    
    test = [[ X_train[i][0] , X_train[i][1] , X_train[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    print ('row [0] data: inside_diameter= ', X_train[i][0]*Dmed, ', solar_flux= ', X_train[i][1]*Qmed, \
        ', mass_flow_rate= ', X_train[i][2]*Mmed,', exit_quality= ', Y_train[i][0]*Xmed,\
        ', Max_temp= ', Y_train[i][1]*Tmed,',  data value exit_quality = ', outpt[0][0]*Xmed,\
           ', data value Max_temp= ', outpt[0][1]*Tmed)
# Out:
# row [0] data: inside_diameter=  0.008 , solar_flux=  850.0 , mass_flow_rate=  0.05286 , exit_quality=  0.9449999999999998 , Max_temp=  291.9 ,  data value exit_quality =  0.8844307565689087 , data value Max_temp=  295.915047454834
# row [0] data: inside_diameter=  0.013 , solar_flux=  750.0 , mass_flow_rate=  0.13644 , exit_quality=  0.524 , Max_temp=  322.3 ,  data value exit_quality =  0.5978764468431472 , data value Max_temp=  332.5142459630966
# row [0] data: inside_diameter=  0.011 , solar_flux=  1150.0 , mass_flow_rate=  0.09834 , exit_quality=  0.9449999999999998 , Max_temp=  295.6 ,  data value exit_quality =  0.8978984713554382 , data value Max_temp=  293.4915358662605
# row [0] data: inside_diameter=  0.011 , solar_flux=  750.0 , mass_flow_rate=  0.1154 , exit_quality=  0.525 , Max_temp=  311.20000000000005 ,  data value exit_quality =  0.6125717014074326 , data value Max_temp=  328.2771234631538
# row [0] data: inside_diameter=  0.013 , solar_flux=  550.0 , mass_flow_rate=  0.05558 , exit_quality=  0.9449999999999998 , Max_temp=  345.3 ,  data value exit_quality =  0.8782059645652771 , data value Max_temp=  316.4818964481354
# row [0] data: inside_diameter=  0.008 , solar_flux=  850.0 , mass_flow_rate=  0.06797 , exit_quality=  0.734 , Max_temp=  291.3 ,  data value exit_quality =  0.8030722939968109 , data value Max_temp=  300.36649423241613
# row [0] data: inside_diameter=  0.008 , solar_flux=  650.0 , mass_flow_rate=  0.07269 , exit_quality=  0.525 , Max_temp=  298.5 ,  data value exit_quality =  0.6486455556750298 , data value Max_temp=  321.03310453891754
# row [0] data: inside_diameter=  0.011 , solar_flux=  550.0 , mass_flow_rate=  0.047 , exit_quality=  0.9449999999999998 , Max_temp=  330.7 ,  data value exit_quality =  0.859711645245552 , data value Max_temp=  314.6156170845032
# row [0] data: inside_diameter=  0.013 , solar_flux=  1050.0 , mass_flow_rate=  0.13302 , exit_quality=  0.735 , Max_temp=  306.29999999999995 ,  data value exit_quality =  0.705850880742073 , data value Max_temp=  315.37298942804335
# row [0] data: inside_diameter=  0.008 , solar_flux=  1150.0 , mass_flow_rate=  0.0919 , exit_quality=  0.735 , Max_temp=  282.5 ,  data value exit_quality =  0.8331131100654602 , data value Max_temp=  289.94575036764144
# row [0] data: inside_diameter=  0.008 , solar_flux=  850.0 , mass_flow_rate=  0.09346999999999998 , exit_quality=  0.525 , Max_temp=  290.2 ,  data value exit_quality =  0.6497737357020378 , data value Max_temp=  314.0574041366577
# row [0] data: inside_diameter=  0.011 , solar_flux=  1150.0 , mass_flow_rate=  0.177 , exit_quality=  0.525 , Max_temp=  293.6 ,  data value exit_quality =  0.59290618121624 , data value Max_temp=  321.9579988837242
# row [0] data: inside_diameter=  0.008 , solar_flux=  950.0 , mass_flow_rate=  0.05908 , exit_quality=  0.9449999999999998 , Max_temp=  288.5 ,  data value exit_quality =  0.8982703256607055 , data value Max_temp=  292.4752163529396
# row [0] data: inside_diameter=  0.013 , solar_flux=  750.0 , mass_flow_rate=  0.09745 , exit_quality=  0.735 , Max_temp=  324.0 ,  data value exit_quality =  0.7450542604923248 , data value Max_temp=  321.52470097541806
# row [0] data: inside_diameter=  0.008 , solar_flux=  1150.0 , mass_flow_rate=  0.0715 , exit_quality=  0.9449999999999998 , Max_temp=  283.1 ,  data value exit_quality =  0.9215629148483276 , data value Max_temp=  287.0810042798519
# row [0] data: inside_diameter=  0.011 , solar_flux=  550.0 , mass_flow_rate=  0.0846 , exit_quality=  0.525 , Max_temp=  327.99999999999994 ,  data value exit_quality =  0.6378939807415008 , data value Max_temp=  329.8704712748527
# row [0] data: inside_diameter=  0.011 , solar_flux=  950.0 , mass_flow_rate=  0.10440000000000002 , exit_quality=  0.735 , Max_temp=  302.0 ,  data value exit_quality =  0.7500524765253067 , data value Max_temp=  309.5396495938301
# row [0] data: inside_diameter=  0.008 , solar_flux=  750.0 , mass_flow_rate=  0.05997 , exit_quality=  0.735 , Max_temp=  295.5 ,  data value exit_quality =  0.7903174459934235 , data value Max_temp=  305.00918197631836
# row [0] data: inside_diameter=  0.011 , solar_flux=  950.0 , mass_flow_rate=  0.08124 , exit_quality=  0.944 , Max_temp=  302.9 ,  data value exit_quality =  0.8894915324449539 , data value Max_temp=  300.17267432808876
# row [0] data: inside_diameter=  0.013 , solar_flux=  750.0 , mass_flow_rate=  0.0758 , exit_quality=  0.944 , Max_temp=  325.1 ,  data value exit_quality =  0.8803266030550003 , data value Max_temp=  312.3276268720627
# row [0] data: inside_diameter=  0.008 , solar_flux=  950.0 , mass_flow_rate=  0.10635 , exit_quality=  0.524 , Max_temp=  286.9 ,  data value exit_quality =  0.6429927831888199 , data value Max_temp=  311.86112967729565
# row [0] data: inside_diameter=  0.008 , solar_flux=  950.0 , mass_flow_rate=  0.07596 , exit_quality=  0.735 , Max_temp=  287.8 ,  data value exit_quality =  0.8142231917381286 , data value Max_temp=  296.391279232502
# row [0] data: inside_diameter=  0.011 , solar_flux=  700.0 , mass_flow_rate=  0.087196 , exit_quality=  0.734 , Max_temp=  324.7 ,  data value exit_quality =  0.6922343015670777 , data value Max_temp=  322.62746939659115
# row [0] data: inside_diameter=  0.008 , solar_flux=  550.0 , mass_flow_rate=  0.04398 , exit_quality=  0.734 , Max_temp=  307.9 ,  data value exit_quality =  0.7579485100507736 , data value Max_temp=  315.3563897848129
# row [0] data: inside_diameter=  0.008 , solar_flux=  750.0 , mass_flow_rate=  0.08396 , exit_quality=  0.525 , Max_temp=  294.5 ,  data value exit_quality =  0.6461162629723549 , data value Max_temp=  317.9584292650223
# row [0] data: inside_diameter=  0.011 , solar_flux=  1050.0 , mass_flow_rate=  0.11340000000000001 , exit_quality=  0.735 , Max_temp=  299.4 ,  data value exit_quality =  0.7582377398014069 , data value Max_temp=  304.79643775224685
# row [0] data: inside_diameter=  0.008 , solar_flux=  1150.0 , mass_flow_rate=  0.1287 , exit_quality=  0.525 , Max_temp=  281.7 ,  data value exit_quality =  0.640839419066906 , data value Max_temp=  307.01530516147614
# row [0] data: inside_diameter=  0.013 , solar_flux=  550.0 , mass_flow_rate=  0.10005000000000001 , exit_quality=  0.525 , Max_temp=  342.2 ,  data value exit_quality =  0.6306825131177902 , data value Max_temp=  332.73149424791336
# row [0] data: inside_diameter=  0.008 , solar_flux=  1050.0 , mass_flow_rate=  0.08343 , exit_quality=  0.735 , Max_temp=  285.0 ,  data value exit_quality =  0.8270416510105133 , data value Max_temp=  292.80844420194626
# row [0] data: inside_diameter=  0.011 , solar_flux=  950.0 , mass_flow_rate=  0.1462 , exit_quality=  0.525 , Max_temp=  300.8 ,  data value exit_quality =  0.5997964382171631 , data value Max_temp=  325.3086931705475
# row [0] data: inside_diameter=  0.013 , solar_flux=  1150.0 , mass_flow_rate=  0.20919999999999997 , exit_quality=  0.525 , Max_temp=  301.6 ,  data value exit_quality =  0.5780839231610299 , data value Max_temp=  328.1565308690071
# row [0] data: inside_diameter=  0.011 , solar_flux=  550.0 , mass_flow_rate=  0.06047000000000001 , exit_quality=  0.735 , Max_temp=  329.6 ,  data value exit_quality =  0.7753682720661164 , data value Max_temp=  320.3713345170021
# row [0] data: inside_diameter=  0.008 , solar_flux=  850.0 , mass_flow_rate=  0.09516 , exit_quality=  0.524 , Max_temp=  290.3 ,  data value exit_quality =  0.6444175091385841 , data value Max_temp=  314.79581583738326
# row [0] data: inside_diameter=  0.008 , solar_flux=  550.0 , mass_flow_rate=  0.0342 , exit_quality=  0.9449999999999998 , Max_temp=  308.6 ,  data value exit_quality =  0.8275477373600006 , data value Max_temp=  310.2166753053665
# row [0] data: inside_diameter=  0.013 , solar_flux=  850.0 , mass_flow_rate=  0.0859 , exit_quality=  0.9449999999999998 , Max_temp=  318.19999999999993 ,  data value exit_quality =  0.8811250734329223 , data value Max_temp=  309.61367601156235
# row [0] data: inside_diameter=  0.011 , solar_flux=  850.0 , mass_flow_rate=  0.1308 , exit_quality=  0.525 , Max_temp=  305.5 ,  data value exit_quality =  0.6051225677132607 , data value Max_temp=  326.92383482456205
# row [0] data: inside_diameter=  0.011 , solar_flux=  1150.0 , mass_flow_rate=  0.1264 , exit_quality=  0.735 , Max_temp=  294.8 ,  data value exit_quality =  0.7357366114854812 , data value Max_temp=  302.9120876610279
# row [0] data: inside_diameter=  0.011 , solar_flux=  850.0 , mass_flow_rate=  0.072691 , exit_quality=  0.944 , Max_temp=  307.7 ,  data value exit_quality =  0.8840560108423233 , data value Max_temp=  304.10510075092316
# row [0] data: inside_diameter=  0.013 , solar_flux=  850.0 , mass_flow_rate=  0.15463 , exit_quality=  0.524 , Max_temp=  315.5 ,  data value exit_quality =  0.5895411363244056 , data value Max_temp=  331.77481721639634

# %%
pred_exit_quality=[]
data_vaue_exit_quality=[]
test=[]
for i in range(len(X_train)):

    test = [[ X_train[i][0] , X_train[i][1] , X_train[i][2]]]
    testarray = np.array(test)
    outpt = model.predict(testarray)
    pred_exit_quality.append(Y_train[i][0]*Xmed)
    data_vaue_exit_quality.append(outpt[0][0]*Xmed)

# %% [markdown]
# ##  create a log-log plot of predicted exit quality vs. data value exit quality

# %%
import matplotlib.pyplot as plt
plt.scatter(pred_exit_quality,data_vaue_exit_quality,s=10, label='Exit quality comparison')
plt.ylabel(r'Data value exct quality ',fontsize = 16)
plt.xlabel(r'Predicted exct quality',fontsize = 16)
plt.title('Predicted exct quality vs. Data value exct quality',fontsize=16)
plt.legend(loc='upper left')
plt.loglog()
plt.show()

# %% [markdown]
# ## Do the same for the maximum wall temperature.

# %%
pred_max_wall_temp=[]
data_max_wall_temp=[]
test2=[]
for i in range(len(X_train)):

    test2 = [[ X_train[i][0] , X_train[i][1] , X_train[i][2]]]
    testarray2 = np.array(test2)
    outpt2 = model.predict(testarray2)
    pred_max_wall_temp.append(Y_train[i][1]*Tmed)
    data_max_wall_temp.append(outpt2[0][1]*Tmed)

# %% [markdown]
# ## Plot these as a scatter plots of data points and show the slope = 1 line for comparison.

# %%
plt.scatter(pred_max_wall_temp,data_max_wall_temp,s=10, label='Max wall temperature comparison')
plt.plot(data_max_wall_temp,data_max_wall_temp,label='Perfect Model Prediciton', color = 'red',linestyle = '--')
plt.ylabel(r'Data value max wall temperature ',fontsize = 12)
plt.xlabel(r'Predicted max wall temperature',fontsize = 16)
plt.title('Predicted max wall temperature vs. Data max wall temperature',fontsize=16)
plt.legend(loc='upper left')
plt.loglog()
plt.show()

# %%
test3 = []
outpt3=[]

for i in range(len(Y_test)):
    
    test3 = [[ X_train[i][0] , X_train[i][1] , X_train[i][2]]]
    testarray3 = np.array(test3)
    outpt3 = model.predict(testarray3)
    print ('row [0] data: inside_diameter= ', X_train[i][0]*Dmed, ', solar_flux= ', X_train[i][1]*Qmed, \
        ', mass_flow_rate= ', X_train[i][2]*Mmed,', exit_quality= ', Y_train[i][0]*Xmed,\
        ', Max_temp= ', Y_train[i][1]*Tmed,',  normalized exit_quality = ', Y_test[i][0]*Xmed,\
           ', normalized Max_temp= ', Y_test[0][1]*Tmed)
# Out:
# row [0] data: inside_diameter=  0.008 , solar_flux=  850.0 , mass_flow_rate=  0.05286 , exit_quality=  0.9449999999999998 , Max_temp=  291.9 ,  normalized exit_quality =  0.734 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.013 , solar_flux=  750.0 , mass_flow_rate=  0.13644 , exit_quality=  0.524 , Max_temp=  322.3 ,  normalized exit_quality =  0.735 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.011 , solar_flux=  1150.0 , mass_flow_rate=  0.09834 , exit_quality=  0.9449999999999998 , Max_temp=  295.6 ,  normalized exit_quality =  0.735 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.011 , solar_flux=  750.0 , mass_flow_rate=  0.1154 , exit_quality=  0.525 , Max_temp=  311.20000000000005 ,  normalized exit_quality =  0.9449999999999998 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.013 , solar_flux=  550.0 , mass_flow_rate=  0.05558 , exit_quality=  0.9449999999999998 , Max_temp=  345.3 ,  normalized exit_quality =  0.735 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.008 , solar_flux=  850.0 , mass_flow_rate=  0.06797 , exit_quality=  0.734 , Max_temp=  291.3 ,  normalized exit_quality =  0.9449999999999998 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.008 , solar_flux=  650.0 , mass_flow_rate=  0.07269 , exit_quality=  0.525 , Max_temp=  298.5 ,  normalized exit_quality =  0.944 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.011 , solar_flux=  550.0 , mass_flow_rate=  0.047 , exit_quality=  0.9449999999999998 , Max_temp=  330.7 ,  normalized exit_quality =  0.9449999999999998 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.013 , solar_flux=  1050.0 , mass_flow_rate=  0.13302 , exit_quality=  0.735 , Max_temp=  306.29999999999995 ,  normalized exit_quality =  0.735 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.008 , solar_flux=  1150.0 , mass_flow_rate=  0.0919 , exit_quality=  0.735 , Max_temp=  282.5 ,  normalized exit_quality =  0.525 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.008 , solar_flux=  850.0 , mass_flow_rate=  0.09346999999999998 , exit_quality=  0.525 , Max_temp=  290.2 ,  normalized exit_quality =  0.524 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.011 , solar_flux=  1150.0 , mass_flow_rate=  0.177 , exit_quality=  0.525 , Max_temp=  293.6 ,  normalized exit_quality =  0.524 , normalized Max_temp=  317.1
# row [0] data: inside_diameter=  0.008 , solar_flux=  950.0 , mass_flow_rate=  0.05908 , exit_quality=  0.9449999999999998 , Max_temp=  288.5 ,  normalized exit_quality =  0.734 , normalized Max_temp=  317.1

# %% [markdown]
# # (f)

# %%
predict_exit_quality=[]
normalized_exit_quality=[]
testpower=[]
test_=[]
for i in range(len(X_test)):
    test_ = [[ X_test[i][0] , X_test[i][1] , X_test[i][2]]]
    testarray = np.array(test_)
    testpower = model.predict(testarray)
    predict_exit_quality.append(Y_test[i][0]*Xmed)
    normalized_exit_quality.append(testpower[0][0]*Xmed)

# %%
import matplotlib.pyplot as plt
plt.scatter(predict_exit_quality,normalized_exit_quality,s=10, label='Exit quality comparison')
plt.ylabel(r'normalized_exit_quality ',fontsize = 16)
plt.xlabel(r'predict_exit_quality',fontsize = 16)
plt.title('predict_exit_quality vs. normalized_exit_quality',fontsize=16)
plt.legend(loc='upper left')
plt.loglog()
plt.show()

# %%
predict_max_wall_temp=[]
normalized_max_wall_temp=[]
testpower2=[]
test2_=[]
for i in range(len(X_test)):
    test2_ = [[ X_test[i][0] , X_test[i][1] , X_test[i][2]]]
    testarray_ = np.array(test2_)
    testpower2 = model.predict(testarray_)
    predict_max_wall_temp.append(Y_test[i][1]*Tmed)
    normalized_max_wall_temp.append(testpower2[0][1]*Tmed)

# %%
plt.scatter(predict_max_wall_temp,normalized_max_wall_temp,s=10, label='Max wall temperature comparison')
plt.plot(normalized_max_wall_temp,normalized_max_wall_temp,label='Perfect Model Prediciton', color = 'red',linestyle = '--')
plt.ylabel(r'normalized_max_wall_temp ',fontsize = 12)
plt.xlabel(r'predict_max_wall_temp',fontsize = 16)
plt.title('predict_max_wall_temp vs. normalized_max_wall_temp',fontsize=16)
plt.legend(loc='upper left')
plt.loglog()
plt.show()

# %%
# This line of code can be used to reconstruct the saved model.

recon_model = keras.models.load_model("best_model")

# the name of the model is now "recon_model". You can then use this model to do predictions for comparisons.
# See the previous project for code to do the comparisons.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cq/vfvrr_h52kvb57f4jtngmpz00000gn/T/ipykernel_5182/4009632779.py in <module>
#       1 # This line of code can be used to reconstruct the saved model.
#       2
# ----> 3 recon_model = keras.models.load_model("best_model")
#       4
#       5 # the name of the model is now "recon_model". You can then use this model to do predictions for comparisons.
#
# /opt/anaconda3/envs/Python3-7_Keras_env/lib/python3.7/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /opt/anaconda3/envs/Python3-7_Keras_env/lib/python3.7/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# /opt/anaconda3/envs/Python3-7_Keras_env/lib/python3.7/site-packages/keras/engine/saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     271     if model_config is None:
#     272         raise ValueError('No model found in config.')
# --> 273     model_config = json.loads(model_config.decode('utf-8'))
#     274     model = model_from_config(model_config, custom_objects=custom_objects)
#     275     model_weights_group = h5dict['model_weights']
#
# AttributeError: 'str' object has no attribute 'decode'
