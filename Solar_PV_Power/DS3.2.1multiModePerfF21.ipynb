# %%
import math, numpy
#Part 2 input data: Mode number, Air temp (degC), ID (W/sqm), load resistance (ohms)
# - split into training and validation sets
xdata = [[0., 10.0, 200.0, 24.3], 
 [1., 10.0, 200.0, 24.3], 
 [2., 10.0, 200.0, 24.3], 
 [0., 10.0, 200.0, 51.8], 
 [1., 10.0, 200.0, 51.8],
         
 [2., 10.0, 200.0, 51.8], 
 [0., 10.0, 200.0, 96.2], 
 [1., 10.0, 200.0, 96.2], 
 [2., 10.0, 200.0, 96.2], 
 [0., 10.0, 200.0, 170.1],
         
 [1., 10.0, 200.0, 170.1], 
 [2., 10.0, 200.0, 170.1], 
 [0., 10.0, 500.0, 7.0], 
 [1., 10.0, 500.0, 7.0], 
 [2., 10.0, 500.0, 7.0], 
         
 [0., 10.0, 500.0, 21.2], 
 [1., 10.0, 500.0, 21.2], 
 [2., 10.0, 500.0, 21.2], 
 [0., 10.0, 500.0, 43.2], 
 [1., 10.0, 500.0, 43.2], 
         
 [2., 10.0, 500.0, 43.2], 
 [0., 10.0, 500.0, 79.1], 
 [1., 10.0, 500.0, 79.1], 
 [2., 10.0, 500.0, 79.1], 
 [0., 10.0, 700.0, 4.9], 
         
 [1., 10.0, 700.0, 4.9], 
 [2., 10.0, 700.0, 4.9], 
 [0., 10.0, 700.0, 14.3], 
 [1., 10.0, 700.0, 14.3], 
 [2., 10.0, 700.0, 14.3], 
         
 [0., 10.0, 700.0, 29.7], 
 [1., 10.0, 700.0, 29.7], 
 [2., 10.0, 700.0, 29.7], 
 [0., 10.0, 700.0, 55.3], 
 [1., 10.0, 700.0, 55.3], 
 [2., 10.0, 700.0, 55.3], 
         
 [0., 10.0, 1000.0, 3.92], 
 [1., 10.0, 1000.0, 3.92], 
 [2., 10.0, 1000.0, 3.92], 
 [0., 10.0, 1000.0, 11.7], 
 [1., 10.0, 1000.0, 11.7], 
         
 [2., 10.0, 1000.0, 11.7], 
 [0., 10.0, 1000.0, 25.2], 
 [1., 10.0, 1000.0, 25.2], 
 [2., 10.0, 1000.0, 25.2], 
 [0., 10.0, 1000.0, 41.6], 
 [1., 10.0, 1000.0, 41.6], 
 [2., 10.0, 1000.0, 41.6]]

#Part 1 output data for above specified Mode and conditons: VL (V) and Power out (W)
ydata = [[46.0, 87.3], 
         [27.9, 64.2], 
         [27.9, 32.1], 
         [46.0, 40.9], 
         [92.1, 163.9], 
         [59.5, 68.5], 
         [46.0, 22.0], 
         [92.1, 88.2], 
         [110.6, 127.2], 
         [46.0, 12.4], 
         [92.1, 49.9], 
         [184.2, 199.6], 
         [48.4, 335.3], 
         [20.8, 124.3], 
         [20.8, 62.1], 
         [48.4, 110.7], 
         [96.8, 442.9], 
         [63.1, 188.2], 
         [48.4, 54.3], 
         [96.9, 217.3], 
         [128.7, 383.6], 
         [48.4, 29.6], 
         [96.8, 118.7], 
         [193.7, 474.8], 
         [49.3, 496.1], 
         [20.4, 171.2], 
         [20.4, 85.6], 
         [49.3, 169.9], 
         [98.6, 679.9], 
         [59.7, 249.8], 
         [49.3, 81.8], 
         [98.6, 327.4], 
         [124.1, 518.9], 
         [49.305, 43.9], 
         [98.6, 175.8], 
         [197.2, 703.3], 
         [50.8, 658.9], 
         [23.1, 272.9], 
         [23.1, 136.4], 
         [50.8, 220.7], 
         [101.6, 883.1], 
         [69.0, 407.2], 
         [50.8, 102.5], 
         [101.6, 410.0], 
         [148.6, 877.2], 
         [50.8, 62.0], 
         [101.6, 248.3], 
         [203.2, 993.5]]

xarray= numpy.array(xdata)
yarray= numpy.array(ydata)
print (xdata)
print (xarray)
print (ydata)
print (yarray)
# Out:
# [[0.0, 10.0, 200.0, 24.3], [1.0, 10.0, 200.0, 24.3], [2.0, 10.0, 200.0, 24.3], [0.0, 10.0, 200.0, 51.8], [1.0, 10.0, 200.0, 51.8], [2.0, 10.0, 200.0, 51.8], [0.0, 10.0, 200.0, 96.2], [1.0, 10.0, 200.0, 96.2], [2.0, 10.0, 200.0, 96.2], [0.0, 10.0, 200.0, 170.1], [1.0, 10.0, 200.0, 170.1], [2.0, 10.0, 200.0, 170.1], [0.0, 10.0, 500.0, 7.0], [1.0, 10.0, 500.0, 7.0], [2.0, 10.0, 500.0, 7.0], [0.0, 10.0, 500.0, 21.2], [1.0, 10.0, 500.0, 21.2], [2.0, 10.0, 500.0, 21.2], [0.0, 10.0, 500.0, 43.2], [1.0, 10.0, 500.0, 43.2], [2.0, 10.0, 500.0, 43.2], [0.0, 10.0, 500.0, 79.1], [1.0, 10.0, 500.0, 79.1], [2.0, 10.0, 500.0, 79.1], [0.0, 10.0, 700.0, 4.9], [1.0, 10.0, 700.0, 4.9], [2.0, 10.0, 700.0, 4.9], [0.0, 10.0, 700.0, 14.3], [1.0, 10.0, 700.0, 14.3], [2.0, 10.0, 700.0, 14.3], [0.0, 10.0, 700.0, 29.7], [1.0, 10.0, 700.0, 29.7], [2.0, 10.0, 700.0, 29.7], [0.0, 10.0, 700.0, 55.3], [1.0, 10.0, 700.0, 55.3], [2.0, 10.0, 700.0, 55.3], [0.0, 10.0, 1000.0, 3.92], [1.0, 10.0, 1000.0, 3.92], [2.0, 10.0
# ...

# %%
import numpy as np

# %%
at_=np.median(xarray[:,1])
id_=np.median(xarray[:,2])
lr_=np.median(xarray[:,3])
vr_=np.median(yarray[:,0])
po_=np.median(yarray[:,1])
Xmedian = [1,at_,id_,lr_]
Ymedian = [vr_,po_]
print(Xmedian)
print(Ymedian)
# Out:
# [1, 10.0, 600.0, 27.45]
# [55.15, 170.55]

# %%
X_nor=xarray/Xmedian
Y_nor=yarray/Ymedian

# %%
X_nor
# Out:
# array([[0.        , 1.        , 0.33333333, 0.8852459 ],
#        [1.        , 1.        , 0.33333333, 0.8852459 ],
#        [2.        , 1.        , 0.33333333, 0.8852459 ],
#        [0.        , 1.        , 0.33333333, 1.8870674 ],
#        [1.        , 1.        , 0.33333333, 1.8870674 ],
#        [2.        , 1.        , 0.33333333, 1.8870674 ],
#        [0.        , 1.        , 0.33333333, 3.50455373],
#        [1.        , 1.        , 0.33333333, 3.50455373],
#        [2.        , 1.        , 0.33333333, 3.50455373],
#        [0.        , 1.        , 0.33333333, 6.19672131],
#        [1.        , 1.        , 0.33333333, 6.19672131],
#        [2.        , 1.        , 0.33333333, 6.19672131],
#        [0.        , 1.        , 0.83333333, 0.25500911],
#        [1.        , 1.        , 0.83333333, 0.25500911],
#        [2.        , 1.        , 0.83333333, 0.25500911],
#        [0.        , 1.        , 0.83333333, 0.7723133 ],
# ...

# %%
Y_nor
# Out:
# array([[0.83408885, 0.51187335],
#        [0.50589302, 0.3764292 ],
#        [0.50589302, 0.1882146 ],
#        [0.83408885, 0.23981237],
#        [1.66999093, 0.9610085 ],
#        [1.07887579, 0.40164175],
#        [0.83408885, 0.12899443],
#        [1.66999093, 0.5171504 ],
#        [2.00543971, 0.74582234],
#        [0.83408885, 0.07270595],
#        [1.66999093, 0.29258282],
#        [3.33998187, 1.17033128],
#        [0.87760653, 1.96599238],
#        [0.37715322, 0.72881853],
#        [0.37715322, 0.36411609],
#        [0.87760653, 0.64907652],
#        [1.75521306, 2.59689241],
#        [1.14415231, 1.10348871],
#        [0.87760653, 0.31838171],
#        [1.75702629, 1.27411316],
#        [2.33363554, 2.24919378],
#        [0.87760653, 0.17355614],
#        [1.75521306, 0.69598358],
#        [3.51223935, 2.78393433],
#        [0.89392566, 2.90882439],
#        [0.36990027, 1.0038112 ],
#        [0.36990027, 0.5019056 ],
#        [0.89392566, 0.9961888 ],
# ...
